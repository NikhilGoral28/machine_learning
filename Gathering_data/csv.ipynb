# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# opening local csv file

# %%
df = pd.read_csv("homeprices (1).csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# Opening a csv file from url

# %%
import requests
from io import StringIO


url = "https://media.geeksforgeeks.org/wp-content/uploads/20241121154629307916/people_data.csv"
req = requests.get(url)
req.raise_for_status()

df = pd.read_csv(StringIO(req.text))

df
# Out:
#   First Name Last Name     Sex                       Email Date of birth  \
# 0     Shelby   Terrell    Male        elijah57@example.net    1945-10-26
# 1    Phillip   Summers  Female       bethany14@example.com    1910-03-24
# 2   Kristine    Travis    Male       bthompson@example.com    1992-07-02
# 3    Yesenia  Martinez    Male   kaitlinkaiser@example.com    2017-08-03
# 4       Lori      Todd    Male  buchananmanuel@example.net    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %% [markdown]
# sep parameter

# %%
pd.read_csv("homeprices (1).csv", sep='\t', names=[])
# Out:
#     area,price
# 0  2600,550000
# 1  3000,565000
# 2  3200,610000
# 3  3600,680000
# 4  4000,725000

# %% [markdown]
# Index_col parameter

# %%
pd.read_csv("homeprices (1).csv", index_col='area')
# Out:
#        price
# area
# 2600  550000
# 3000  565000
# 3200  610000
# 3600  680000
# 4000  725000

# %% [markdown]
# Header parameter

# %%
pd.read_csv("homeprices (1).csv", header=1)
# Out:
#    2600  550000
# 0  3000  565000
# 1  3200  610000
# 2  3600  680000
# 3  4000  725000

# %% [markdown]
# use col parameter

# %%
pd.read_csv("homeprices (1).csv", usecols=['area','price'])
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# squeeze parameters

# %%
pd.read_csv("homeprices (1).csv", usecols=['area'], squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.read_csv("homeprices (1).csv", usecols=['area'], squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# skip rows/nrows parameter

# %%
pd.read_csv("homeprices (1).csv", nrows=90) #this will give the number of rows
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# Encoding parameter

# %%
pd.read_csv('',encoding='encoding name')  #used for the encoded csv

# %% [markdown]
# skip bad lines

# %%
pd.read_csv('',sep=',', encoding='encoder name',error_bad_lines = False)  # for having a mismatched columns

# %% [markdown]
# Dtypes

# %%
pd.read_csv("homeprices (1).csv", dtype={'area': int}).info()  # used to convert the datatype of a column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 208.0 bytes

# %% [markdown]
# handling dates

# %%
pd.read_csv('',parse_dates=['date'])   # to keep the date datatype not in character or convert the char data to date

# %% [markdown]
# convertors

# %%
pd.read_csv('',converters={'team1':rename})  #creating a short name to long names using other user defined functions

# %% [markdown]
# na_values parameter

# %%
pd.read_csv("homeprices (1).csv",na_values=['-'])   #specify the values to be a null values (- = null)

# %% [markdown]
# loading a huge dataset in chunks

# %%
df = pd.read_csv("homeprices (1).csv", chunksize=50)  #to divide the huge data into chunks

# %%
for chunks in df:
    print(chunks.shape)
# Out:
# (5, 2)
