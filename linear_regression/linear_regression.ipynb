# %%
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("homeprices (1).csv")

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("Area in square feet")
plt.ylabel("Price in US Dollars")
plt.scatter(df.area, df.price, color='red', marker='+')

# %%
rg = linear_model.LinearRegression()

rg.fit(df[['area']], df.price)  # double brackets to make it 2D array
# Out:
# LinearRegression()

# %%
rg.predict([[3300]])
# Out:
# c:\Users\nikhi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
rg.coef_
# Out:
# array([135.78767123])

# %%
rg.intercept_
# Out:
# np.float64(180616.43835616432)
